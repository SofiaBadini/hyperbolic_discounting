# %% [markdown]
# # Simulation exercise (based on Keane and Wolpin, 1994)

# %% [markdown]
# 1. Choice Frequencies ([model 1](#Choices1), [model 2](#Choices2), [model 3](#Choices3))
# 2. Wages ([model 1](#Wages1), [model 2](#Wages2), [model 3](#Wages3))
# 3. Mean Experience ([model 1](#MeanExp1), [model 2](#MeanExp2), [model 3](#MeanExp3))
# 4. Final Experience ([model 1](#FinalExp1), [model 2](#FinalExp2), [model 3](#FinalExp3))
# 5. Utility ([model 1](#Utility1), [model 2](#Utility2), [model 3](#Utility3))

# %%
from python.auxiliary import *

# Set seaborn style
sns.set_style("white")
sns.set_context("paper", font_scale=1.5)

# %% [markdown]
# ## Keane and Wolpin (1994) - Model 1
# ***

# %%
# Generate datasets (exponential case)
# generate_data(model="kw_94_one", present_bias=1)

# %%
# Generate datasets (hyperbolic case)
# generate_data(model="kw_94_one", present_bias=0.88)

# %%
# Load data
data_exp_one = load_data("kw_94_one", "exp")
data_hyp_one = load_data("kw_94_one", "hyp")

# %% [markdown]
# ## Choice Frequencies <a class="anchor" id="Choices1"></a>

# %% [markdown]
# Choice frequencies for [model 2](#Choices2) and [model 3](#Choices3)

# %%
compare_choice_frequencies(data_exp_one, data_hyp_one)

# %% [markdown]
# ## Wages <a class="anchor" id="Wages1"></a>

# %% [markdown]
# Wages for [model 2](#Wages2) and [model 3](#Wages3)

# %%
compare_wages(data_exp_one, data_hyp_one)

# %% [markdown]
# ## Mean Experience per Period <a class="anchor" id="MeanExp1"></a>

# %% [markdown]
# Mean experience for [model 2](#MeanExp2) and [model 3](#MeanExp3)

# %%
compare_mean_experience(data_exp_one, data_hyp_one)

# %% [markdown]
# ## Distribution of Final Experience <a class="anchor" id="FinalExp1"></a>

# %% [markdown]
# Final experience for [model 2](#FinalExp2) and [model 3](#FinalExp3)

# %%
compare_final_experience(data_exp_one, data_hyp_one)

# %% [markdown]
# ## Utility <a class="anchor" id="Utility1"></a>

# %% [markdown]
# Utility for [model 2](#Utility2) and [model 3](#Utility3)

# %%
plot_moment(
    data_exp_one,
    data_hyp_one,
    func=compute_utility_per_period,
    plot="line",
    moment="utility_per_period",
    title="Utility per Period",
)

# %%
compare_total_utility(data_exp_one, data_hyp_one)

# %% [markdown]
# ## Keane and Wolpin (1994) - Model 2
# ***

# %%
# Generate datasets (exponential case)
# generate_data(model="kw_94_two", present_bias=1)

# %%
# Generate datasets (hyperbolic case)
# generate_data(model="kw_94_two", present_bias=0.88)

# %%
# Load data
data_exp_two = load_data("kw_94_two", "exp")
data_hyp_two = load_data("kw_94_two", "hyp")

# %% [markdown]
# ## Choice Frequencies <a class="anchor" id="Choices2"></a>

# %% [markdown]
# Choice frequencies for [model 1](#Choices1) and [model 3](#Choices3)

# %%
compare_choice_frequencies(data_exp_two, data_hyp_two)

# %% [markdown]
# ## Wages <a class="anchor" id="Wages2"></a>

# %% [markdown]
# Wages for [model 1](#Wages1) and [model 3](#Wages3)

# %%
compare_wages(data_exp_two, data_hyp_two)

# %% [markdown]
# ## Mean Experience per Period <a class="anchor" id="MeanExp2"></a>

# %% [markdown]
# Mean experience for [model 1](#MeanExp1) and [model 3](#MeanExp3)

# %%
compare_mean_experience(data_exp_two, data_hyp_two)

# %% [markdown]
# ## Distribution of Final Experience <a class="anchor" id="FinalExp2"></a>

# %% [markdown]
# Final experience for [model 1](#FinalExp1) and [model 3](#FinalExp3)

# %%
compare_final_experience(data_exp_two, data_hyp_two)

# %% [markdown]
# ## Utility <a class="anchor" id="Utility2"></a>

# %% [markdown]
# Utility for [model 1](#Utility1) and [model 3](#Utility3)

# %%
plot_moment(
    data_exp_two,
    data_hyp_two,
    func=compute_utility_per_period,
    plot="line",
    moment="utility_per_period",
    title="Utility per Period",
)

# %%
compare_total_utility(data_exp_two, data_hyp_two)

# %% [markdown]
# ## Keane and Wolpin (1994) - Model 3
# ***

# %%
# Generate datasets (exponential case)
# generate_data(model="kw_94_three", present_bias=1)

# %%
# Generate datasets (hyperbolic case)
# generate_data(model="kw_94_three", present_bias=0.88)

# %%
# Load data
data_exp_three = load_data("kw_94_three", "exp")
data_hyp_three = load_data("kw_94_three", "hyp")

# %% [markdown]
# ## Choice Frequencies <a class="anchor" id="Choices3"></a>

# %% [markdown]
# Choice frequencies for [model 1](#Choices1) and [model 2](#Choices2)

# %%
compare_choice_frequencies(data_exp_three, data_hyp_three)

# %% [markdown]
# ## Wages <a class="anchor" id="Wages3"></a>

# %% [markdown]
# Wages for [model 1](#Wages1) and [model 2](#Wages2)

# %%
compare_wages(data_exp_three, data_hyp_three)

# %% [markdown]
# ## Mean Experience per Period <a class="anchor" id="MeanExp3"></a>

# %% [markdown]
# Mean experience for [model 1](#MeanExp1) and [model 2](#MeanExp2)

# %%
compare_mean_experience(data_exp_three, data_hyp_three)

# %% [markdown]
# ## Distribution of Final Experience <a class="anchor" id="FinalExp3"></a>

# %% [markdown]
# Final experience for [model 1](#FinalExp1) and [model 2](#FinalExp2)

# %%
compare_final_experience(data_exp_three, data_hyp_three)

# %% [markdown]
# ## Utility <a class="anchor" id="Utility3"></a>

# %% [markdown]
# Utility for [model 1](#Utility1) and [model 2](#Utility2)

# %%
plot_moment(
    data_exp_three,
    data_hyp_three,
    func=compute_utility_per_period,
    plot="line",
    moment="utility_per_period",
    title="Utility per Period",
)

# %%
compare_total_utility(data_exp_three, data_hyp_three)
